# %%
import json
from time import sleep
import requests
import pandas as pd

# %%
# ID로 문제정보 가져오기
def get_problemData(problem_id):
    """
     solved.ac에서 문제 정보를 받아옴
     too_many_request 에러가 발생하면 중단
     존재하지 않는 문제의 경우 예외 발생
     100번째마다 로그 출력
    """
    try:
        url = f"https://solved.ac/api/v3/problem/show?problemId={problem_id}"
        r_profile = requests.get(url)
        if r_profile.status_code == requests.codes.too_many_requests: 
            return False
        
        profile = json.loads(r_profile.content.decode('utf-8'))
        tag = ""
        tags = profile.get("tags")
        for t in tags:
            tag += t['key'] +','
            
        problem = \
                {
                    "problemId": profile.get("problemId"),
                    "titleKo": profile.get("titleKo"),
                    "isSolvable": profile.get("isSolvable"),
                    "isPartial" : profile.get("isPartial"),
                    "acceptedUserCount" : profile.get("acceptedUserCount"),
                    "level" : profile.get("level"),
                    "votedUserCount" : profile.get("votedUserCount"),
                    "sprout" : profile.get("sprout"),
                    "givesNoRating" : profile.get("givesNoRating"),
                    "isLevelLocked" : profile.get("isLevelLocked"),
                    "averageTries" : profile.get("averageTries"),
                    "official" : profile.get("official"),
                    "tag" : tag
                }
        if problem_id % 100 == 0:
            print(f"Completed {problem_id}")
            
        return problem
    
    except Exception as e:    
        print(f'{problem_id}에서 예외가 발생했습니다.', e)

# ID로 문제정보를 가져오고 데이터 프레임 및 엑셀파일로 저장
def run_problemData(start,end): 
    """
     solved.ac에서 문제정보를 받아옴
     입력 파라미터 start번부터 end번까지의 문제 정보를 받아옴
     too_many_request 에러가 발생하면 500초 동안 중단
     모두 받아온 후에 result 폴더를 생성한 뒤 data.csv로 저장
    """
    allProblem = []

    for id in range(start,end+1):

        result = get_problemData(id)
        if result == False: 
            print(f"{id}번째 처리 중 Error 429 발생")
            sleep(500)
        else:
            allProblem.append(result)

    df = pd .DataFrame()
    for pro in allProblem:
        df = df.append(pro,ignore_index = True)
    df.to_csv("result/data.csv")

# %%
run_problemData(16000,25000)
# Out:
# Completed 16000
# Completed 16100
# Completed 16200
# Completed 16300
# Completed 16400
# Completed 16500
# Completed 16600
# Completed 16700
# Completed 16800
# Completed 16900
# 16901번째 처리 중 Error 429 발생
# 16902번째 처리 중 Error 429 발생
# 16962에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 16963에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 17000
# 17061에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17062에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17063에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17064에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17065에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17066에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17067에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17068에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 17100
# 17125에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17183에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17189에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 17200
# Completed 17300
# Completed 17400
# Completed 17500
# Completed 17600
# Completed 17700
# 17714에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17725에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17727에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17732에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17740에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17751에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 17770에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 17800
# 17804번째 처리 중 Error 429 발생
# 17805번째 처리 중 Error 429 발생
# Completed 17900
# Completed 18000
# Completed 18100
# Completed 18200
# Completed 18300
# 18367에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 18369에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 18400
# 18492에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 18500
# Completed 18600
# Completed 18700
# 18707번째 처리 중 Error 429 발생
# 18708번째 처리 중 Error 429 발생
# 18797에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 18800
# Completed 18900
# Completed 19000
# Completed 19100
# Completed 19200
# Completed 19300
# Completed 19400
# Completed 19500
# Completed 19600
# 19610번째 처리 중 Error 429 발생
# 19611번째 처리 중 Error 429 발생
# 19633에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 19700
# 19714에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 19715에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 19716에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 19717에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 19800
# Completed 19900
# Completed 20000
# 20022에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 20100
# 20163에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 20200
# Completed 20300
# 20356에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 20357에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 20371에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 20392에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 20393에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 20400
# 20404에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 20406에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 20407에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 20500
# 20513번째 처리 중 Error 429 발생
# 20514번째 처리 중 Error 429 발생
# Completed 20600
# Completed 20700
# Completed 20800
# Completed 20900
# Completed 21000
# Completed 21100
# Completed 21200
# Completed 21300
# Completed 21400
# 21416번째 처리 중 Error 429 발생
# 21417번째 처리 중 Error 429 발생
# Completed 21500
# Completed 21600
# 21689에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 21690에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 21693에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 21694에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 21700
# Completed 21800
# 21805에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 21859에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 21900
# 22000에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22001에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22002에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22003에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22004에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22005에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22006에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22009에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22013에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 22100
# 22192에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 22200
# 22247에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22248에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22249에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22250에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 22300
# 22318에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22319번째 처리 중 Error 429 발생
# 22320번째 처리 중 Error 429 발생
# 22321에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22322에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22323에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22324에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22325에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22326에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22328에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22332에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22333에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22334에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22335에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22336에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22337에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22338에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22339에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 22340에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 22400
# Completed 22500
# Completed 22600
# Completed 22700
# Completed 22800
# 22888에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 22900
# Completed 23000
# Completed 23100
# Completed 23200
# 23222번째 처리 중 Error 429 발생
# 23223번째 처리 중 Error 429 발생
# Completed 23300
# 23346에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 23400
# Completed 23500
# Completed 23600
# Completed 23700
# Completed 23800
# Completed 23900
# Completed 24000
# 24096에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 24100
# 24106에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24125번째 처리 중 Error 429 발생
# 24126번째 처리 중 Error 429 발생
# 24150에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24151에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24152에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24153에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24154에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24160에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24166에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24167에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24168에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24169에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24170에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 24200
# 24203에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24204에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24205에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24206에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24207에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24208에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24209에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24210에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24211에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24212에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24213에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24214에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24215에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24216에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# 24217에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 24300
# Completed 24400
# Completed 24500
# Completed 24600
# Completed 24700
# Completed 24800
# 24898에서 예외가 발생했습니다. Expecting value: line 1 column 1 (char 0)
# Completed 24900
# Completed 25000
